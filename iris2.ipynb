# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier 
import numpy as np

df = pd.read_csv(r"C:\Users\48666\Documents\Python Scripts\iris\Iris.csv")
train_df = df.sample(frac = 0.75)
test_df = df.drop(train_df.index)

# %%
X = train_df[["PetalLengthCm","PetalWidthCm"]]
y = train_df["Species"]
knn = KNeighborsClassifier(10)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
test = test_df[["PetalLengthCm","PetalWidthCm"]]
predictions = knn.predict(test)

# %%
print('predictions: {}'.format(predictions))
# Out:
# predictions: ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %%
ytest = test_df["Species"]
print(knn.score(test,ytest))
# Out:
# 0.9210526315789473

# %%
train_accuracies = {}
test_accuracies = {}
neighbors = np.arange(1,26)
for neighbor in neighbors:
    knn = KNeighborsClassifier(n_neighbors=neighbor)
    knn.fit(X,y)
    train_accuracies[neighbor] = knn.score(X,y)
    test_accuracies[neighbor] = knn.score(test,ytest)

# %%
plt.figure(figsize=(8,6))
plt.title("KNN")
plt.plot(neighbors,train_accuracies.values(),label = "Train accurarcy")
plt.plot(neighbors,test_accuracies.values(),label = "Test accurarcy")
plt.legend()
plt.xlabel("Neighbors")
plt.ylabel("accuracy")
plt.show()
